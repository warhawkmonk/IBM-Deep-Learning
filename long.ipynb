# %%
import numpy as np
from PIL  import Image
import matplotlib.pyplot as plt
import tensorflow as tf
h=tf.keras.datasets.fashion_mnist
(l,m),(z,a)=h.load_data()
xc=['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']
l=l/255
z=z/255
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10)
])
model.compile(optimizer='adam',
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
model.fit(l,m,epochs=10)
f,g=model.evaluate(z,a,verbose=2)
print(g)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6360 - accuracy: 0.7781
# Epoch 2/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3778 - accuracy: 0.8631
# Epoch 3/10
# 1875/1875 [==============================] - 2s 954us/step - loss: 0.3424 - accuracy: 0.8751
# Epoch 4/10
# 1875/1875 [==============================] - 2s 956us/step - loss: 0.3094 - accuracy: 0.8858
# Epoch 5/10
# 1875/1875 [==============================] - 2s 930us/step - loss: 0.2939 - accuracy: 0.8919
# Epoch 6/10
# 1875/1875 [==============================] - 2s 948us/step - loss: 0.2740 - accuracy: 0.8982
# Epoch 7/10
# 1875/1875 [==============================] - 2s 938us/step - loss: 0.2706 - accuracy: 0.8992
# Epoch 8/10
# 1875/1875 [==============================] - 2s 936us/step - loss: 0.2535 - accuracy: 0.9063
# Epoch 9/10
# 1875/1875 [==============================] - 2s 947us/step - loss: 0.2458 - accuracy: 0.9086
# Epoch 10/10
# 1875/1875 [==============================] - 2s 971us/step - loss: 0.2354 - accuracy: 0.9129
# 313/313 - 0s - loss: 0.3447 - accuracy: 0.8824
# 0.8823999762535095
